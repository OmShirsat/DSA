# %% [markdown]
# <a href="https://colab.research.google.com/github/OmShirsat/DSA/blob/main/pandasbasic_and_T_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv",skiprows=4)
df
# Out:
#          City  Edition     Sport Discipline                Athlete  NOC  \
# 0      Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN
# 1      Athens     1896  Aquatics   Swimming       HERSCHMANN, Otto  AUT
# 2      Athens     1896  Aquatics   Swimming      DRIVAS, Dimitrios  GRE
# 3      Athens     1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE
# 4      Athens     1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE
# ...       ...      ...       ...        ...                    ...  ...
# 41352  Sydney     2000   Fencing    Fencing       WEBER, Alexander  GER
# 41353  Sydney     2000   Fencing    Fencing      CHARIKOV, Serguei  RUS
# 41354  Sydney     2000   Fencing    Fencing       FROSSINE, Alexei  RUS
# 41355  Sydney     2000   Fencing    Fencing  POZDNYAKOV, Stanislav  RUS
# 41356  Sydney     2000   Fencing    Fencing      GOURDAIN, Mathieu  FRA
#
#       Gender                       Event Event_gender   Medal
# ...

# %%
df.head() #first five lines
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df.tail()#last five lines
# Out:
#          City  Edition    Sport Discipline                Athlete  NOC Gender  \
# 41352  Sydney     2000  Fencing    Fencing       WEBER, Alexander  GER    Men
# 41353  Sydney     2000  Fencing    Fencing      CHARIKOV, Serguei  RUS    Men
# 41354  Sydney     2000  Fencing    Fencing       FROSSINE, Alexei  RUS    Men
# 41355  Sydney     2000  Fencing    Fencing  POZDNYAKOV, Stanislav  RUS    Men
# 41356  Sydney     2000  Fencing    Fencing      GOURDAIN, Mathieu  FRA    Men
#
#             Event Event_gender   Medal
# 41352  sabre team            M  Bronze
# 41353  sabre team            M    Gold
# 41354  sabre team            M    Gold
# 41355  sabre team            M    Gold
# 41356  sabre team            M  Silver

# %%
df.sample(10)#randomly print record
# Out:
#               City  Edition       Sport   Discipline                 Athlete  \
# 24304       Sydney     2000  Gymnastics  Artistic G.       BERESH, Oleksandr
# 40662       Sydney     2000    Aquatics   Water polo           SHEEHY, Kathy
# 36311        Seoul     1988        Judo         Judo    VAN DE WALLE, Robert
# 6008   Los Angeles     1932     Fencing      Fencing  SHEARS, Curtis Charles
# 22409      Atlanta     1996  Gymnastics  Rhythmic G.          DELTCHEVA, Ina
# 28694      Beijing     2008      Rowing       Rowing          BARABAS, Eniko
# 5557     Amsterdam     1928      Rowing       Rowing   O'BRIEN, Terence Noel
# 22262      Atlanta     1996    Football     Football              PAZ, Pablo
# 27887      Beijing     2008  Basketball   Basketball          SNELL, Belinda
# 38159    Barcelona     1992      Rowing       Rowing     THORSEN, Rolf Bernt
#
#        NOC Gender                                   Event Event_gender   Medal
# ...

# %%
df[["City","Medal"]]
# Out:
#          City   Medal
# 0      Athens    Gold
# 1      Athens  Silver
# 2      Athens  Bronze
# 3      Athens    Gold
# 4      Athens  Silver
# ...       ...     ...
# 41352  Sydney  Bronze
# 41353  Sydney    Gold
# 41354  Sydney    Gold
# 41355  Sydney    Gold
# 41356  Sydney  Silver
#
# [41357 rows x 2 columns]
# ...
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Medal').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df.City
# Out:
# 0        Athens
# 1        Athens
# 2        Athens
# 3        Athens
# 4        Athens
#           ...
# 41352    Sydney
# 41353    Sydney
# 41354    Sydney
# 41355    Sydney
# 41356    Sydney
# Name: City, Length: 41357, dtype: object

# %%
df[df.Medal=="Gold"]
# Out:
#          City  Edition      Sport Discipline                Athlete  NOC  \
# 0      Athens     1896   Aquatics   Swimming          HAJOS, Alfred  HUN
# 3      Athens     1896   Aquatics   Swimming     MALOKINIS, Ioannis  GRE
# 6      Athens     1896   Aquatics   Swimming          HAJOS, Alfred  HUN
# 9      Athens     1896   Aquatics   Swimming          NEUMANN, Paul  AUT
# 13     Athens     1896  Athletics  Athletics          BURKE, Thomas  USA
# ...       ...      ...        ...        ...                    ...  ...
# 41342  Sydney     2000    Fencing    Fencing     VEZZALI, Valentina  ITA
# 41348  Sydney     2000    Fencing    Fencing         COVALIU, Mihai  ROU
# 41353  Sydney     2000    Fencing    Fencing      CHARIKOV, Serguei  RUS
# 41354  Sydney     2000    Fencing    Fencing       FROSSINE, Alexei  RUS
# 41355  Sydney     2000    Fencing    Fencing  POZDNYAKOV, Stanislav  RUS
#
#       Gender                       Event Event_gender Medal
# ...

# %%
df.shape
# Out:
# (41357, 10)

# %%
df.describe()
# Out:
#             Edition
# count  41357.000000
# mean    1972.916217
# std       28.866795
# min     1896.000000
# 25%     1960.000000
# 50%     1980.000000
# 75%     1996.000000
# max     2008.000000

# %%
df.Medal.unique()
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %%
df.to_csv('New.csv')

# %%
df[df.Medal=="Gold"].mean()
# Out:
# <ipython-input-30-eaf35de2576d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df.Medal=="Gold"].mean()
# Edition    1971.976892
# dtype: float64

# %%
df2=pd.read_csv("father_son.csv")
df2
# Out:
#       Father   Son
# 0       65.0  59.8
# 1       63.3  63.2
# 2       65.0  63.3
# 3       65.8  62.8
# 4       61.1  64.3
# ...      ...   ...
# 1073    67.0  70.8
# 1074    71.3  68.3
# 1075    71.8  69.3
# 1076    70.7  69.3
# 1077    70.3  67.0
#
# [1078 rows x 2 columns]

# %%
df2.head(5)
# Out:
#    Father   Son
# 0    65.0  59.8
# 1    63.3  63.2
# 2    65.0  63.3
# 3    65.8  62.8
# 4    61.1  64.3

# %%
df2.tail(5)
# Out:
#       Father   Son
# 1073    67.0  70.8
# 1074    71.3  68.3
# 1075    71.8  69.3
# 1076    70.7  69.3
# 1077    70.3  67.0

# %%
df2.Father
# Out:
# 0       65.0
# 1       63.3
# 2       65.0
# 3       65.8
# 4       61.1
#         ...
# 1073    67.0
# 1074    71.3
# 1075    71.8
# 1076    70.7
# 1077    70.3
# Name: Father, Length: 1078, dtype: float64

# %%
df2.shape
# Out:
# (1078, 2)

# %%
df2.describe()
# Out:
#             Father          Son
# count  1078.000000  1078.000000
# mean     67.686827    68.684230
# std       2.745827     2.816194
# min      59.000000    58.500000
# 25%      65.800000    66.900000
# 50%      67.800000    68.600000
# 75%      69.600000    70.500000
# max      75.400000    78.400000
